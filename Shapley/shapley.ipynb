# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
pip install shap
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.7/dist-packages (0.40.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from shap) (1.1.5)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.7/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from shap) (1.3.0)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.7/dist-packages (from shap) (21.3)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.7/dist-packages (from shap) (4.62.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from shap) (1.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from shap) (1.4.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from shap) (0.51.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shap) (1.19.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>20.9->shap) (3.0.6)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->shap) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->shap) (57.4.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->shap) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->shap) (1.1.0)

# %%
import os
import random
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf   
import tensorflow.compat.v1.keras.backend as K
tf.compat.v1.disable_eager_execution()
from tensorflow import keras
from tensorflow.keras.models import load_model
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.utils import shuffle

import shap
import json

print("SHAP version is:", shap.__version__)
print("Tensorflow version is:", tf.__version__)
# Out:
# SHAP version is: 0.40.0
# Tensorflow version is: 2.7.0

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
print(tf.test.gpu_device_name())
# Out:
# /device:GPU:0

# %%
seed = 123
random.seed(seed) # Python
np.random.seed(seed) # numpy
tf.random.set_seed(seed) 
os.environ['PYTHONHASHSEED'] = str(seed)

# %%
base_dir = '/content/gdrive/MyDrive/research/images'
train_dir = os.path.join(base_dir, 'train')  
test_dir = os.path.join(base_dir, 'test')

# %%
class_name = os.listdir(train_dir)
class_name_test = os.listdir(test_dir)
print(class_name)
print(class_name_test)
# Out:
# ['american_makeup', 'korean_makeup']
# ['american_makeup', 'korean_makeup']

# %%
integer_encoded = LabelEncoder().fit_transform(class_name)
integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
onehot_encoded = OneHotEncoder(sparse=False).fit_transform(integer_encoded)
print(onehot_encoded)

integer_encoded_test = LabelEncoder().fit_transform(class_name_test)
integer_encoded_test = integer_encoded_test.reshape(len(integer_encoded_test), 1)
onehot_encoded_test = OneHotEncoder(sparse=False).fit_transform(integer_encoded_test)

print(onehot_encoded_test)
# Out:
# [[1. 0.]
#  [0. 1.]]
# [[1. 0.]
#  [0. 1.]]

# %%
train_image = []
train_label = []
test_image = []
test_label = []

# %%
for i in range(len(class_name)):
    path = os.path.join(train_dir, class_name[i])
    img_list = os.listdir(path)
    for j in img_list:
        img = os.path.join(path, j)
        img = cv2.imread(img, cv2.IMREAD_COLOR)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (100, 100), interpolation = cv2.INTER_CUBIC)    
        img = img.reshape((100, 100, 3)) 
        train_image.append(img)
        train_label.append(onehot_encoded[i])

# %%
plt.imshow(train_image[0])

# %%
for i in range(len(class_name_test)):
    path = os.path.join(test_dir, class_name_test[i])
    img_list = os.listdir(path)
    for j in img_list:
        img = os.path.join(path, j)
        img = cv2.imread(img, cv2.IMREAD_COLOR)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (100, 100), interpolation = cv2.INTER_CUBIC)    
        img = img.reshape((100, 100, 3)) 
        test_image.append(img)
        test_label.append(onehot_encoded_test[i])

# %%
plt.imshow(test_image[11])

# %%
print(len((train_image)), len(train_label)) 
print(len(test_image), len(test_label))

train_image = np.array(train_image)
train_label = np.array(train_label)
print(train_image.shape)
print(train_label.shape)

test_image = np.array(test_image)
test_label = np.array(test_label)
print(test_image.shape)
print(test_label.shape)
# Out:
# 283 283
# 20 20
# (283, 100, 100, 3)
# (283, 2)
# (20, 100, 100, 3)
# (20, 2)

# %%
X_train = shuffle(train_image.reshape(283, 100, 100, 3).astype("float32") / 255, random_state = seed)
X_test = shuffle(test_image.reshape(20, 100, 100, 3).astype("float32") / 255, random_state = seed)

train_label = shuffle(train_label, random_state = seed)
test_label = shuffle(test_label, random_state = seed)

# %%
def CNN():
    input_layer = keras.Input(shape=(100,100,3))
    x = keras.layers.Conv2D(150, (3,3), padding='same', activation = 'relu', kernel_initializer = keras.initializers.HeUniform(seed=seed))(input_layer)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2))(x)
    x = keras.layers.Conv2D(150, (3,3), padding='same', activation = 'relu', kernel_initializer = keras.initializers.HeUniform(seed=seed))(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2))(x)
    x = keras.layers.Conv2D(150, (3,3), padding='same', activation = 'relu', kernel_initializer = keras.initializers.HeUniform(seed=seed))(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2))(x)
    x = keras.layers.Conv2D(150, (3,3), padding='same', activation = 'relu', kernel_initializer = keras.initializers.HeUniform(seed=seed))(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.MaxPooling2D((2, 2))(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(128, activation='relu', kernel_initializer = keras.initializers.HeUniform(seed=seed))(x)
    x = keras.layers.Dropout(0.5)(x)
    output_layer = keras.layers.Dense(2, activation='sigmoid')(x)
    model = keras.Model(inputs=input_layer, outputs=output_layer, name = 'CNN')
    model.compile(loss='binary_crossentropy', optimizer= keras.optimizers.SGD(learning_rate=0.001),  metrics=['acc', 'AUC'])
    return model

# %%
model = CNN()
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/layers/normalization/batch_normalization.py:532: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100, 100, 3)]     0
#
#  conv2d (Conv2D)             (None, 100, 100, 150)     4200
#
#  batch_normalization (BatchN  (None, 100, 100, 150)    600
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 150)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 150)       202650
#
#  batch_normalization_1 (Batc  (None, 50, 50, 150)      600
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 150)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 150)       202650
#
#  batch_normalization_2 (Batc  (None, 25, 25, 150)      600
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 150)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 150)       202650
#
#  batch_normalization_3 (Batc  (None, 12, 12, 150)      600
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 150)        0
#  2D)
#
#  flatten (Flatten)           (None, 5400)              0
#
#  dense (Dense)               (None, 128)               691328
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 1,306,136
# Trainable params: 1,304,936
# Non-trainable params: 1,200
# _________________________________________________________________

# %%
model.fit(X_train, train_label,  batch_size=16, epochs=250, validation_data=(X_test, test_label))
# Out:
# Train on 283 samples, validate on 20 samples
# Epoch 1/250
# 283/283 [==============================] - ETA: 0s - loss: 1.0938 - acc: 0.5265 - AUC: 0.5362
# `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
# 283/283 [==============================] - 4s 16ms/sample - loss: 1.0938 - acc: 0.5265 - AUC: 0.5362 - val_loss: 0.8723 - val_acc: 0.5000 - val_AUC: 0.6100
# Epoch 2/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.8437 - acc: 0.6007 - AUC: 0.6628 - val_loss: 0.7742 - val_acc: 0.5000 - val_AUC: 0.6125
# Epoch 3/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.7256 - acc: 0.6731 - AUC: 0.7287 - val_loss: 0.7639 - val_acc: 0.5000 - val_AUC: 0.6025
# Epoch 4/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.6351 - acc: 0.7226 - AUC: 0.7799 - val_loss: 0.7293 - val_acc: 0.5250 - val_AUC: 0.5950
# Epoch 5/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.5366 - acc: 0.7138 - AUC: 0.8220 - val_loss: 0.7187 - val_acc: 0.5500 - val_AUC: 0.5838
# Epoch 6/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.4455 - acc: 0.7668 - AUC: 0.8704 - val_loss: 0.7024 - val_acc: 0.5500 - val_AUC: 0.6087
# Epoch 7/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.4266 - acc: 0.7827 - AUC: 0.8834 - val_loss: 0.6940 - val_acc: 0.5500 - val_AUC: 0.6075
# Epoch 8/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.3897 - acc: 0.8163 - AUC: 0.9033 - val_loss: 0.6776 - val_acc: 0.5250 - val_AUC: 0.6213
# Epoch 9/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0
- acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4589 - val_acc: 0.8000 - val_AUC: 0.8825
# Epoch 75/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0463 - acc: 0.9929 - AUC: 0.9998 - val_loss: 0.4812 - val_acc: 0.7750 - val_AUC: 0.8738
# Epoch 76/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0439 - acc: 0.9929 - AUC: 0.9998 - val_loss: 0.4646 - val_acc: 0.7750 - val_AUC: 0.8925
# Epoch 77/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0463 - acc: 0.9929 - AUC: 0.9998 - val_loss: 0.4369 - val_acc: 0.8000 - val_AUC: 0.8988
# Epoch 78/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0359 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4535 - val_acc: 0.7750 - val_AUC: 0.8925
# Epoch 79/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0458 - acc: 0.9894 - AUC: 0.9998 - val_loss: 0.4780 - val_acc: 0.7750 - val_AUC: 0.8800
# Epoch 80/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0347 - acc: 0.9947 - AUC: 1.0000 - val_loss: 0.4521 - val_acc: 0.7750 - val_AUC: 0.8913
# Epoch 81/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0447 - acc: 0.9929 - AUC: 0.9997 - val_loss: 0.4416 - val_acc: 0.7750 - val_AUC: 0.8975
# Epoch 82/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0402 - acc: 0.9947 - AUC: 0.9996 - val_loss: 0.4504 - val_acc: 0.8000 - val_AUC: 0.8950
# Epoch 83/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0321 - acc: 0.9965 - AUC: 1.0000 - val_loss: 0.4526 - val_acc: 0.8000 - val_AUC: 0.8938
# Epoch 84/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0420 - acc: 0.9947 - AUC: 0.9999 - val_loss: 0.4186 - val_acc: 0.8000 - val_AUC: 0.9050
# Epoch 85/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0345 - acc: 0.9947 - AUC: 0.9999 - val_loss: 0.4220 - val_acc: 0.8000 - val_AUC: 0.9025
# Epoch 86/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0348 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4430 - val_acc: 0.8000 - val_AUC: 0.8975
# Epoch 87/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0314 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4482 - val_acc: 0.8000 - val_AUC: 0.8988
# Epoch 88/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0293 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4659 - val_acc: 0.8000 - val_AUC: 0.8888
# Epoch 89/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0413 - acc: 0.9912 - AUC: 0.9998 - val_loss: 0.4439 - val_acc: 0.8000 - val_AUC: 0.9000
# Epoch 90/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0335 - acc: 0.9947 - AUC: 1.0000 - val_loss: 0.4490 - val_acc: 0.8000 - val_AUC: 0.8975
# Epoch 91/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0324 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4352 - val_acc: 0.8000 - val_AUC: 0.9013
# Epoch 92/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0360 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000 - val_AUC: 0.9038
# Epoch 93/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0359 - acc: 0.9912 - AUC: 0.9999 - val_loss: 0.4393 - val_acc: 0.8000 - val_AUC: 0.9025
# Epoch 94/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0348 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4465 - val_acc: 0.8000 - val_AUC: 0.8963
# Epoch 95/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0293 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4411 - val_acc: 0.8000 - val_AUC: 0.9037
# Epoch 96/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0322 - acc: 0.9947 - AUC: 0.9998 - val_loss: 0.4149 - val_acc: 0.8000 - val_AUC: 0.9112
# Epoch 97/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0353 - acc: 0.9929 - AUC: 1.0000 - val_loss: 0.4016 - val_acc: 0.8000 - val_AUC: 0.9162
# Epoch 98/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0235 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4196 - val_acc: 0.8000 - val_AUC: 0.9100
# Epoch 99/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0361 - acc: 0.9947 - AUC: 1.0000 - val_loss: 0.4095 - val_acc: 0.8000 - val_AUC: 0.9125
# Epoch 100/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0290 - acc: 0.9965 - AUC: 1.0000 - val_loss: 0.4265 - val_acc: 0.8000 - val_AUC: 0.9087
# Epoch 101/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0390 - acc: 0.9894 - AUC: 0.9996 - val_loss: 0.3993 - val_acc: 0.8250 - val_AUC: 0.9138
# Epoch 102/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0247 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4252 - val_acc: 0.8000 - val_AUC: 0.9087
# Epoch 103/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0388 - acc: 0.9859 - AUC: 0.9996 - val_loss: 0.3814 - val_acc: 0.8000 - val_AUC: 0.9213
# Epoch 104/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0345 - acc: 0.9912 - AUC: 0.9998 - val_loss: 0.3870 - val_acc: 0.8000 - val_AUC: 0.9188
# Epoch 105/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0350 - acc: 0.9929 - AUC: 1.0000 - val_loss: 0.4076 - val_acc: 0.8000 - val_AUC: 0.9112
# Epoch 106/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0260 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4102 - val_acc: 0.8000 - val_AUC: 0.9137
# Epoch 107/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0375 - acc: 0.9982 - AUC: 0.9999 - val_loss: 0.3853 - val_acc: 0.8000 - val_AUC: 0.9263
# Epoch 108/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0334 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.3900 - val_acc: 0.8000 - val_AUC: 0.9238
# Epoch 109/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0233 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.3817 - val_acc: 0.8000 - val_AUC: 0.9238
# Epoch 110/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0234 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4050 - val_acc: 0.8000 - val_AUC: 0.9187
# Epoch 111/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0327 - acc: 0.9929 - AUC: 0.9998 - val_loss: 0.4157 - val_acc: 0.8000 - val_AUC: 0.9125
# Epoch 112/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0215 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4228 - val_acc: 0.8000 - val_AUC: 0.9125
# Epoch 113/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0280 - acc: 0.9965 - AUC: 1.0000 - val_loss: 0.4204 - val_acc: 0.8000 - val_AUC: 0.9137
# Epoch 114/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0315 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.3960 - val_acc: 0.8000 - val_AUC: 0.9187
# Epoch 115/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0271 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4155 - val_acc: 0.8000 - val_AUC: 0.9137
# Epoch 116/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0260 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4355 - val_acc: 0.8000 - val_AUC: 0.9025
# Epoch 117/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0242 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4352 - val_acc: 0.8000 - val_AUC: 0.9037
# Epoch 118/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0208 - acc: 0.9965 - AUC: 1.0000 - val_loss: 0.4434 - val_acc: 0.8000 - val_AUC: 0.9025
# Epoch 119/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0255 - acc: 0.9947 - AUC: 0.9999 - val_loss: 0.4258 - val_acc: 0.8000 - val_AUC: 0.9075
# Epoch 120/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0255 - acc: 0.9982 - AUC: 0.9999 - val_loss: 0.4529 - val_acc: 0.8000 - val_AUC: 0.9000
# Epoch 121/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0214 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4638 - val_acc: 0.8000 - val_AUC: 0.9000
# Epoch 122/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0250 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4495 - val_acc: 0.8000 - val_AUC: 0.8962
# Epoch 123/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0229 - acc: 0.9965 - AUC: 0.9998 - val_loss: 0.4608 - val_acc: 0.8000 - val_AUC: 0.8987
# Epoch 124/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0204 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4407 - val_acc: 0.8000 - val_AUC: 0.9037
# Epoch 125/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0211 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4200 - val_acc: 0.8000 - val_AUC: 0.9100
# Epoch 126/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0341 - acc: 0.9894 - AUC: 0.9997 - val_loss: 0.4490 - val_acc: 0.8000 - val_AUC: 0.9012
# Epoch 127/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0212 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4562 - val_acc: 0.8000 - val_AUC: 0.8987
# Epoch 128/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0219 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4733 - val_acc: 0.8000 - val_AUC: 0.8925
# Epoch 129/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0242 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4470 - val_acc: 0.8000 - val_AUC: 0.9000
# Epoch 130/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0216 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4672 - val_acc: 0.8000 - val_AUC: 0.8925
# Epoch 131/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0231 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4410 - val_acc: 0.8000 - val_AUC: 0.9025
# Epoch 132/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0224 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4694 - val_acc: 0.7750 - val_AUC: 0.8900
# Epoch 133/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0281 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4452 - val_acc: 0.8000 - val_AUC: 0.9025
# Epoch 134/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0183 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4283 - val_acc: 0.8000 - val_AUC: 0.9075
# Epoch 135/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0151 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4330 - val_acc: 0.8000 - val_AUC: 0.9050
# Epoch 136/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0228 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000 - val_AUC: 0.9050
# Epoch 137/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0259 - acc: 0.9947 - AUC: 0.9999 - val_loss: 0.4203 - val_acc: 0.8000 - val_AUC: 0.9138
# Epoch 138/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0188 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4228 - val_acc: 0.8000 - val_AUC: 0.9125
# Epoch 139/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0258 - acc: 0.9982 - AUC: 0.9999 - val_loss: 0.4148 - val_acc: 0.8000 - val_AUC: 0.9150
# Epoch 140/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0160 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4154 - val_acc: 0.8000 - val_AUC: 0.9150
# Epoch 141/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0177 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4112 - val_acc: 0.8000 - val_AUC: 0.9150
# Epoch 142/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0203 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4226 - val_acc: 0.8000 - val_AUC: 0.9150
# Epoch 143/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0210 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4137 - val_acc: 0.8000 - val_AUC: 0.9150
# Epoch 144/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0145 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4203 - val_acc: 0.8000 - val_AUC: 0.9137
# Epoch 145/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0206 - acc: 0.9965 - AUC: 1.0000 - val_loss: 0.4380 - val_acc: 0.8000 - val_AUC: 0.9037
# Epoch 146/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0210 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4390 - val_acc: 0.8000 - val_AUC: 0.9050
# Epoch 147/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0220 - acc: 0.9965 - AUC: 1.0000 - val_loss: 0.4130 - val_acc: 0.8000 - val_AUC: 0.9150
# Epoch 148/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0170 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4376 - val_acc: 0.8000 - val_AUC: 0.9075
# Epoch 149/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0196 - acc: 0.9982 - AUC: 0.9999 - val_loss: 0.4371 - val_acc: 0.8000 - val_AUC: 0.9038
# Epoch 150/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0194 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4543 - val_acc: 0.8000 - val_AUC: 0.9012
# Epoch 151/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0182 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4422 - val_acc: 0.8000 - val_AUC: 0.9050
# Epoch 152/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0241 - acc: 0.9965 - AUC: 1.0000 - val_loss: 0.4236 - val_acc: 0.8000 - val_AUC: 0.9087
# Epoch 153/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0235 - acc: 0.9947 - AUC: 0.9999 - val_loss: 0.4274 - val_acc: 0.8000 - val_AUC: 0.9137
# Epoch 154/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0245 - acc: 0.9929 - AUC: 0.9999 - val_loss: 0.4277 - val_acc: 0.8000 - val_AUC: 0.9150
# Epoch 155/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0182 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4242 - val_acc: 0.8250 - val_AUC: 0.9137
# Epoch 156/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0139 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4225 - val_acc: 0.8250 - val_AUC: 0.9112
# Epoch 157/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0146 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4301 - val_acc: 0.8000 - val_AUC: 0.9100
# Epoch 158/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0154 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4512 - val_acc: 0.8000 - val_AUC: 0.9062
# Epoch 159/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0163 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4326 - val_acc: 0.8000 - val_AUC: 0.9050
# Epoch 160/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0201 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4322 - val_acc: 0.8000 - val_AUC: 0.9075
# Epoch 161/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0147 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4215 - val_acc: 0.8000 - val_AUC: 0.9125
# Epoch 162/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0173 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4367 - val_acc: 0.8000 - val_AUC: 0.9075
# Epoch 163/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0168 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4467 - val_acc: 0.8000 - val_AUC: 0.9050
# Epoch 164/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0218 - acc: 0.9965 - AUC: 1.0000 - val_loss: 0.4406 - val_acc: 0.8000 - val_AUC: 0.9075
# Epoch 165/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0193 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4270 - val_acc: 0.8000 - val_AUC: 0.9125
# Epoch 166/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0171 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4225 - val_acc: 0.8000 - val_AUC: 0.9150
# Epoch 167/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0150 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4057 - val_acc: 0.8250 - val_AUC: 0.9250
# Epoch 168/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0138 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.3945 - val_acc: 0.8250 - val_AUC: 0.9325
# Epoch 169/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0158 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.3989 - val_acc: 0.8250 - val_AUC: 0.9300
# Epoch 170/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0095 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4156 - val_acc: 0.8000 - val_AUC: 0.9212
# Epoch 171/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0143 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4366 - val_acc: 0.8000 - val_AUC: 0.9100
# Epoch 172/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0144 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4167 - val_acc: 0.8000 - val_AUC: 0.9200
# Epoch 173/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0234 - acc: 0.9965 - AUC: 0.9999 - val_loss: 0.3812 - val_acc: 0.8000 - val_AUC: 0.9300
# Epoch 174/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0132 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.3863 - val_acc: 0.8000 - val_AUC: 0.9313
# Epoch 175/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0134 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.3905 - val_acc: 0.8000 - val_AUC: 0.9263
# Epoch 176/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0138 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.3925 - val_acc: 0.8000 - val_AUC: 0.9275
# Epoch 177/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0137 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.3948 - val_acc: 0.8000 - val_AUC: 0.9250
# Epoch 178/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0191 - acc: 0.9965 - AUC: 1.0000 - val_loss: 0.4104 - val_acc: 0.8000 - val_AUC: 0.9200
# Epoch 179/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0125 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4132 - val_acc: 0.8000 - val_AUC: 0.9175
# Epoch 180/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0138 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4090 - val_acc: 0.8000 - val_AUC: 0.9212
# Epoch 181/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0161 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4147 - val_acc: 0.8000 - val_AUC: 0.9162
# Epoch 182/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0183 - acc: 0.9965 - AUC: 1.0000 - val_loss: 0.4174 - val_acc: 0.8000 - val_AUC: 0.9150
# Epoch 183/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0136 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4276 - val_acc: 0.8000 - val_AUC: 0.9125
# Epoch 184/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0146 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4378 - val_acc: 0.8000 - val_AUC: 0.9125
# Epoch 185/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0138 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4202 - val_acc: 0.8000 - val_AUC: 0.9125
# Epoch 186/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0160 - acc: 0.9965 - AUC: 1.0000 - val_loss: 0.4553 - val_acc: 0.8000 - val_AUC: 0.9050
# Epoch 187/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0126 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4397 - val_acc: 0.8000 - val_AUC: 0.9087
# Epoch 188/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0098 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4211 - val_acc: 0.8000 - val_AUC: 0.9162
# Epoch 189/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0190 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4044 - val_acc: 0.8250 - val_AUC: 0.9225
# Epoch 190/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0087 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4029 - val_acc: 0.8250 - val_AUC: 0.9200
# Epoch 191/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0102 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4131 - val_acc: 0.8250 - val_AUC: 0.9212
# Epoch 192/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0121 - acc: 0.9965 - AUC: 1.0000 - val_loss: 0.4104 - val_acc: 0.8250 - val_AUC: 0.9175
# Epoch 193/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0211 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.3917 - val_acc: 0.8250 - val_AUC: 0.9275
# Epoch 194/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0166 - acc: 0.9965 - AUC: 1.0000 - val_loss: 0.3922 - val_acc: 0.8250 - val_AUC: 0.9288
# Epoch 195/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0128 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.3841 - val_acc: 0.8250 - val_AUC: 0.9300
# Epoch 196/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0086 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.3867 - val_acc: 0.8250 - val_AUC: 0.9300
# Epoch 197/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0089 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.3888 - val_acc: 0.8250 - val_AUC: 0.9288
# Epoch 198/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0099 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.3980 - val_acc: 0.8250 - val_AUC: 0.9250
# Epoch 199/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0143 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4072 - val_acc: 0.8250 - val_AUC: 0.9212
# Epoch 200/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0087 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4107 - val_acc: 0.8250 - val_AUC: 0.9212
# Epoch 201/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0095 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4230 - val_acc: 0.8000 - val_AUC: 0.9162
# Epoch 202/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0097 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4322 - val_acc: 0.8000 - val_AUC: 0.9137
# Epoch 203/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0101 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4525 - val_acc: 0.8000 - val_AUC: 0.9075
# Epoch 204/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0163 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4368 - val_acc: 0.8250 - val_AUC: 0.9150
# Epoch 205/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0161 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4401 - val_acc: 0.8250 - val_AUC: 0.9112
# Epoch 206/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0130 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4255 - val_acc: 0.8250 - val_AUC: 0.9188
# Epoch 207/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0117 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4310 - val_acc: 0.8250 - val_AUC: 0.9163
# Epoch 208/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0105 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4190 - val_acc: 0.8250 - val_AUC: 0.9187
# Epoch 209/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0113 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4071 - val_acc: 0.8250 - val_AUC: 0.9200
# Epoch 210/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0141 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4102 - val_acc: 0.8250 - val_AUC: 0.9200
# Epoch 211/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0141 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4249 - val_acc: 0.8250 - val_AUC: 0.9200
# Epoch 212/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0076 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4342 - val_acc: 0.8250 - val_AUC: 0.9150
# Epoch 213/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0109 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4348 - val_acc: 0.8250 - val_AUC: 0.9150
# Epoch 214/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0125 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4295 - val_acc: 0.8250 - val_AUC: 0.9175
# Epoch 215/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0155 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4324 - val_acc: 0.8250 - val_AUC: 0.9187
# Epoch 216/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0105 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4399 - val_acc: 0.8250 - val_AUC: 0.9125
# Epoch 217/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0130 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4558 - val_acc: 0.8000 - val_AUC: 0.9075
# Epoch 218/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0127 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4262 - val_acc: 0.8250 - val_AUC: 0.9187
# Epoch 219/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0094 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4256 - val_acc: 0.8250 - val_AUC: 0.9200
# Epoch 220/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0113 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4380 - val_acc: 0.8250 - val_AUC: 0.9162
# Epoch 221/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0136 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4560 - val_acc: 0.8000 - val_AUC: 0.9062
# Epoch 222/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0087 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4616 - val_acc: 0.8000 - val_AUC: 0.9062
# Epoch 223/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0139 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4547 - val_acc: 0.8000 - val_AUC: 0.9137
# Epoch 224/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0086 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4445 - val_acc: 0.8250 - val_AUC: 0.9137
# Epoch 225/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0098 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4380 - val_acc: 0.8250 - val_AUC: 0.9150
# Epoch 226/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0128 - acc: 0.9965 - AUC: 1.0000 - val_loss: 0.4471 - val_acc: 0.8250 - val_AUC: 0.9075
# Epoch 227/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0120 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4303 - val_acc: 0.8250 - val_AUC: 0.9162
# Epoch 228/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0112 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4264 - val_acc: 0.8250 - val_AUC: 0.9162
# Epoch 229/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0078 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4292 - val_acc: 0.8250 - val_AUC: 0.9162
# Epoch 230/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0108 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4120 - val_acc: 0.8250 - val_AUC: 0.9175
# Epoch 231/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0093 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4153 - val_acc: 0.8250 - val_AUC: 0.9213
# Epoch 232/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0091 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4170 - val_acc: 0.8250 - val_AUC: 0.9175
# Epoch 233/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0107 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4207 - val_acc: 0.8250 - val_AUC: 0.9175
# Epoch 234/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0098 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4179 - val_acc: 0.8250 - val_AUC: 0.9225
# Epoch 235/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0103 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4151 - val_acc: 0.8250 - val_AUC: 0.9213
# Epoch 236/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0111 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4098 - val_acc: 0.8250 - val_AUC: 0.9225
# Epoch 237/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0099 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4114 - val_acc: 0.8250 - val_AUC: 0.9200
# Epoch 238/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0076 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4106 - val_acc: 0.8250 - val_AUC: 0.9200
# Epoch 239/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0067 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4054 - val_acc: 0.8250 - val_AUC: 0.9225
# Epoch 240/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0115 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.3986 - val_acc: 0.8250 - val_AUC: 0.9238
# Epoch 241/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0141 - acc: 0.9965 - AUC: 1.0000 - val_loss: 0.4114 - val_acc: 0.8250 - val_AUC: 0.9212
# Epoch 242/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0118 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4190 - val_acc: 0.8250 - val_AUC: 0.9212
# Epoch 243/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0133 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4409 - val_acc: 0.8250 - val_AUC: 0.9162
# Epoch 244/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0085 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4333 - val_acc: 0.8250 - val_AUC: 0.9162
# Epoch 245/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0123 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4178 - val_acc: 0.8250 - val_AUC: 0.9187
# Epoch 246/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0090 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4286 - val_acc: 0.8250 - val_AUC: 0.9175
# Epoch 247/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0082 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4410 - val_acc: 0.8250 - val_AUC: 0.9162
# Epoch 248/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0113 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4425 - val_acc: 0.8250 - val_AUC: 0.9150
# Epoch 249/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0086 - acc: 0.9982 - AUC: 1.0000 - val_loss: 0.4412 - val_acc: 0.8250 - val_AUC: 0.9150
# Epoch 250/250
# 283/283 [==============================] - 1s 5ms/sample - loss: 0.0107 - acc: 1.0000 - AUC: 1.0000 - val_loss: 0.4246 - val_acc: 0.8250 - val_AUC: 0.9200

# %%
idx = 6
input_val = X_test[idx:idx+1]
output_val = model.predict(input_val)
real = test_label[idx:idx+1]
print("Prediction : ", np.argmax(output_val))
print("Ground Truth : ", np.argmax(real))

plt.imshow(
  input_val.reshape(100, 100, 3),
  interpolation='nearest')
plt.show()
# Out:
# Prediction :  1
# Ground Truth :  1

# %%
results = model.evaluate(X_test, test_label)
print('test loss, test acc, test auc:', results)
# Out:
# test loss, test acc, test auc: [0.4245772361755371, 0.825, 0.92]

# %%
prediction = []
label = []
for idx in range(20): 
  prediction.append(np.argmax(model.predict(X_test[idx:idx+1])))
  label.append(np.argmax(test_label[idx:idx+1]))

df = pd.DataFrame({'Predcition': prediction, 'Label': label})

# %%
df
# Out:
#     Predcition  Label
# 0            1      1
# 1            0      0
# 2            0      0
# 3            1      1
# 4            1      0
# 5            1      0
# 6            1      1
# 7            1      1
# 8            0      0
# 9            1      1
# 10           1      1
# 11           0      0
# 12           1      1
# 13           1      1
# 14           0      0
# 15           0      0
# 16           1      0
# 17           1      1
# 18           0      0
# 19           1      1

# %%
background = X_test
e = shap.DeepExplainer(model, background)
# Out:
# keras is no longer supported, please use tf.keras instead.
# Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/shap/explainers/tf_utils.py:28: The name tf.keras.backend.get_session is deprecated. Please use tf.compat.v1.keras.backend.get_session instead.

# %%
# reduced batch(16) and input dimension(100) and gpu
shap_values = e.shap_values(X_test[0:20])

# %%
shap.image_plot(shap_values, X_test[0:20])

# %%
shap.image_plot(shap_values, X_test[[4,5,16]])
